# %%
# !pip install "transformers[torch]"
# Out:
# Requirement already satisfied: transformers[torch] in /usr/local/lib/python3.12/dist-packages (5.0.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (3.29.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.11.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.2 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (2.10.0+cu128)
# Requirement already satisfied: accelerate>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from accelerate>=1.1.0->transformers[torch]) (5.9.5)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers[torch]) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers[torch]) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers[torch]) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers[torch]) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<2.0,>=1.3.0->transformers[torch]) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (81.0.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.1.6)
# Requirement already satisfied: cuda-bindings==12.9.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.9.4)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.4.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.4.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (1.13.1.3)
# Requirement already satisfied: triton==3.6.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.2->transformers[torch]) (3.6.0)
# Requirement already satisfied: cuda-pathfinder~=1.1 in /usr/local/lib/python3.12/dist-packages (from cuda-bindings==12.9.4->torch>=2.2->transformers[torch]) (1.5.3)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (0.16.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.2->transformers[torch]) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (0.0.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.2->transformers[torch]) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface-hub<2.0,>=1.3.0->transformers[torch]) (0.1.2)

# %%
from transformers import pipeline

classifier = pipeline('sentiment-analysis')
classifier("I am joyful.")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json:   0%|          | 0.00/629 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/268M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/104 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# [{'label': 'POSITIVE', 'score': 0.9998868703842163}]

# %% [markdown]
# Playing with zero shot classification

# %%
classifier =  pipeline('zero-shot-classification')
classifier('Lionel Messi came first in ballondor list followed by Cristiano Ronaldo ',
          candidate_labels = ['positive','negative','neutral'])
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'sequence': 'Lionel Messi came first in ballondor list followed by Cristiano Ronaldo ',
#  'labels': ['positive', 'negative', 'neutral'],
#  'scores': [0.7486535906791687, 0.17900432646274567, 0.07234208285808563]}

# %%
generator = pipeline('text-generation')
generator("I am having fun,", num_return_sequences  = 1,max_length = 50)  #providing num_return_sequences and max_length value inorder to make the model provide only one sequence of output with total 50 words.
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ---------------------+------------+--+-
# h.{0...11}.attn.bias | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# Passing `generation_config` together with generation-related arguments=({'max_length', 'num_return_sequences'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'I am having fun, I am trying hard. I am working hard. I am getting better, I am improving. And my wife is getting better. I am getting better. I am getting better."\n\nAdvertisement Continue reading the main story\n\n"And that\'s the part where they\'re like, \'Oh, man, that\'s cool, man,\' " Mr. Smith said. "They\'re like, \'We do know that we love you, so what are you doing?\' And you\'re like, \'Well, I\'m not making money off of this, so what are you doing?\' And they say, \'Well, you\'re making money off of this, and you\'re getting better, so what are you doing?\' "\n\nAnd then they\'re like, \'God, are you going to be okay?\' " Mr. Smith said. "And they\'re like, \'I\'m going to be fine.\'"\n\nMr. Smith has been in the business for about two years, as did Mr. Smith\'s wife, Sarah, who lives in Detroit. Their first son, a freshman at Middlebury College, is about to attend, so they can help him grow up in a new city.\n\nBut there have been other moments when Mr. Smith has looked down'}]

# %%
classifier = pipeline('zero-shot-classification')
classifier('I love to dance',candidate_labels=['art','science','sports'])  #assigning the labels to the model so that the model can predict which label does the sentence suits more
# Out:
# No model was supplied, defaulted to facebook/bart-large-mnli and revision d7645e1.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Loading weights:   0%|          | 0/515 [00:00<?, ?it/s]
# {'sequence': 'I love to dance',
#  'labels': ['art', 'sports', 'science'],
#  'scores': [0.6665936708450317, 0.2068690061569214, 0.12653733789920807]}

# %% [markdown]
# Text summarization

# %%
article = "By default, React Compiler will memoize your code based on its analysis and heuristics. In most cases, this memoization will be as precise, or moreso, than what you may have written. However, in some cases developers may need more control over memoization. The useMemo and useCallback hooks can continue to be used with React Compiler as an escape hatch to provide control over which values are memoized. A common use-case for this is if a memoized value is used as an effect dependency, in order to ensure that an effect does not fire repeatedly even when its dependencies do not meaningfully change. For new code, we recommend relying on the compiler for memoization and using useMemo/useCallback where needed to achieve precise control. For existing code, we recommend either leaving existing memoization in place (removing it can change compilation output) or carefully testing before removing the memoization."

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
model_id = 'Falconsai/text_summarization'  #repo of the model in huggingface
tokenizer = AutoTokenizer.from_pretrained(model_id)  #extraction of the necessary tokenizer
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)  #extraction of the required model
inputs = tokenizer(article,return_tensors="pt", truncation=True).input_ids   #conversion of the article into tokens with the help of tokenizer
#with the help of truncation, we can limit the number of input tokens within the threshold of number of tokens that can be accepted by the model.
output = model.generate(inputs,max_new_tokens = 500, do_sample=False)   #models generated summary 
summary = tokenizer.decode(output[0],skip_special_tokens=True)  #decoding the output in the human undestandable form
print(summary)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/131 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# ization.ization is used as an escape hatch to provide precise control over which values are memoized. For new code, we recommend either leaving existing memoization in place (removing it can change compilation output) or carefully testing before removing the memoization.

# %%
# !pip install huggingface_hub
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (1.11.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.4.3)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (26.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.3)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (0.24.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (4.13.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub) (3.13)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub) (0.16.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (8.3.3)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub) (0.1.2)

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# Use of openai large language model

# %%
import os
from huggingface_hub import InferenceClient
client = InferenceClient()
completion = client.chat.completions.create(
    model = "openai/gpt-oss-120b",
    messages = [
        
        {
            "role": "user",
            "content": "Explain me the term cosmos in simple language"
        }
    ]
)
print(completion.choices[0].message)
# Out:
# ChatCompletionOutputMessage(role='assistant', content='**Cosmos – what it means in plain words**\n\n- **The whole thing:**  \n  “Cosmos” is a fancy way of saying *everything that exists* – all the stars, planets, galaxies, empty space, time, energy, and the rules that make them work.\n\n- **A tidy, ordered universe:**  \n  The word comes from the Greek *kosmos*, which originally meant “order” or “a well‑arranged thing.” So when people talk about the cosmos they’re thinking of the universe as a big, organized system, not a random mess.\n\n- **What’s inside it:**  \n  • **Space** – the vast emptiness where everything floats.  \n  • **Matter** – the stuff that makes up stars, planets, people, etc.  \n  • **Energy** – light, heat, and the forces that hold things together.  \n  • **Time** – the “when” that lets events happen.\n\n- **How we use the word:**  \n  *Scientists* use “cosmos” when they study the universe as a whole (cosmology).  \n  *Poets or philosophers* use it to talk about the grand, beautiful order of existence.\n\n**In a nutshell:**  \nThe cosmos is just the entire, orderly universe – all space, matter, energy, and time put together as one giant, organized whole.', reasoning='The user asks: "Explain me the term cosmos in simple language". They want a simple explanation of the term "cosmos". Need to be clear, simple language, maybe define as universe, order, etc. Should be concise but thorough. Probably include that it\'s the universe as a whole, all matter, space, time, ordered system; contrast with "chaos". Might mention that cosmos is often used to describe the universe in a scientific or philosophical context, includes stars, planets, galaxies, etc. Provide examples. Include possibly etymology. Keep simple.\n\nReturn answer.', tool_call_id=None, tool_calls=None)

# %% [markdown]
# Use of the model to fill the masked word

# %%
unmasker = pipeline('fill-mask',model = 'bert-base-cased')
unmasker('Hi, I want to [MASK] with you.',top_k = 2)  #here we are using top_k as 2 inorder to provide only 2 outputs
# Out:
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/436M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: bert-base-cased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.weight | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# [{'score': 0.2369413822889328,
#   'token': 2037,
#   'token_str': 'talk',
#   'sequence': 'Hi, I want to talk with you.'},
#  {'score': 0.14481021463871002,
#   'token': 1129,
#   'token_str': 'be',
#   'sequence': 'Hi, I want to be with you.'}]

# %% [markdown]
# Name entity recognition model

# %%
ner_model = pipeline("ner", aggregation_strategy="simple")  #here with the help of aggregation_strategy function we are able to group the two words asok tamang in the same word category 
ner_model('I am Asok Tamang and she is Sylvia Grey,I am from Nepal and She is from Canada.')  #so the letter case of the name of the person as well as the place or country matters for name entity recognition model
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/998 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.33G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# BertForTokenClassification LOAD REPORT from: dbmdz/bert-large-cased-finetuned-conll03-english
# Key                      | Status     |  |
# -------------------------+------------+--+-
# bert.pooler.dense.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# tokenizer_config.json:   0%|          | 0.00/60.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# [{'entity_group': 'PER',
#   'score': np.float32(0.9984022),
#   'word': 'Asok Tamang',
#   'start': 5,
#   'end': 16},
#  {'entity_group': 'PER',
#   'score': np.float32(0.9994389),
#   'word': 'Sylvia Grey',
#   'start': 28,
#   'end': 39},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.9996886),
#   'word': 'Nepal',
#   'start': 50,
#   'end': 55},
#  {'entity_group': 'LOC',
#   'score': np.float32(0.99982077),
#   'word': 'Canada',
#   'start': 72,
#   'end': 78}]

# %% [markdown]
# Question answering model

# %%
question_ans_model = pipeline('question-answering')
question_ans_model(
    question = 'when was peter born?',
    context = 'peter is spiderman character. He was born in year 1994.'
)
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-cased-distilled-squad and revision 564e9b5.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json:   0%|          | 0.00/473 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/261M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/102 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/49.0 [00:00<?, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# {'score': 0.6600423455238342, 'start': 50, 'end': 54, 'answer': '1994'}

# %%
import transformers
print(transformers.__version__)
# Out:
# 5.0.0

# %%
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM
article = 'Dance is an art form, consisting of sequences of body movements with aesthetic and often symbolic value, either improvised or purposefully selected. Dance can be categorized and described by its choreography, by its repertoire of movements or by its historical period or place of origin. Dance is typically performed with musical accompaniment, and sometimes with the dancer simultaneously using a musical instrument themselves. Two common types of group dance are theatrical and participatory dance. Both types of dance may have special functions, whether social, ceremonial, competitive, erotic, martial, sacred or liturgical. Dance is not solely restricted to performance, as dance is used as a form of exercise and occasionally training for other sports and activities. Dance performances and dancing competitions are found across the world exhibiting various different styles and standards. Dance may also be participated in alone as a form of exercise or self expression. Dancing is common human behaviour, and does not necessarily require specific choreography.'
model_id = 'facebook/bart-large-cnn'  #repo of the model in huggingface
tokenizer = AutoTokenizer.from_pretrained(model_id)  #extraction of the necessary tokenizer
model = AutoModelForSeq2SeqLM.from_pretrained(model_id)  #extraction of the required model
inputs = tokenizer(article,return_tensors="pt", truncation=True)   #conversion of the article into tokens with the help of tokenizer
#with the help of truncation, we can limit the number of input tokens within the threshold of number of tokens that can be accepted by the model.
output = model.generate(inputs['input_ids'],max_length = 60, min_length = 10)   #models generated summary 
summary = tokenizer.decode(output[0],skip_special_tokens=True)
print(summary)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights:   0%|          | 0/511 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Dance is an art form, consisting of sequences of body movements with aesthetic and often symbolic value. Dance can be categorized and described by its choreography, by its repertoire of movements or by its historical period or place of origin. Two common types of group dance are theatrical and participatory

# %% [markdown]
# Importing the necessary tokenizer and the model for the language translation

# %%
from transformers import MBartForConditionalGeneration, MBart50TokenizerFast
model = MBartForConditionalGeneration.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
tokenizer = MBart50TokenizerFast.from_pretrained("facebook/mbart-large-50-many-to-many-mmt")
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/2.44G [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/516 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/261 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/529 [00:00<?, ?B/s]
# sentencepiece.bpe.model:   0%|          | 0.00/5.07M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/649 [00:00<?, ?B/s]

# %% [markdown]
# checking whether the model can catch the slang or no

# %%
nepali_text = 'बबाल छ!'
tokenizer.src_lang = 'ne_NP'  #setting the source language to our tokenizer
trns_lang = 'en_XX'     #the targeted language
encoded_txt = tokenizer(nepali_text, return_tensors="pt")  #converting the given text into tokens for the model
generated_tokens = model.generate(**encoded_txt,forced_bos_token_id=tokenizer.lang_code_to_id[trns_lang])
tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
# Out:
# "It's Babel!"

# %% [markdown]
# As we can see, the model hasnot been trained on the slang

# %%
eng_text = 'I love you.'
tokenizer.src_lang = 'en_XX'   #setting the source language to our tokenizer
trns_lang =  'fr_XX'   #the targeted language
encoded_txt = tokenizer(eng_text, return_tensors="pt")  #converting the given text into tokens for the model
generated_tokens = model.generate(**encoded_txt,forced_bos_token_id=tokenizer.lang_code_to_id[trns_lang])
tokenizer.batch_decode(generated_tokens, skip_special_tokens=True)[0]
# Out:
# 'Je vous ai aimé.'

# %% [markdown]
# Image classification model

# %%
from PIL import Image

image = Image.open("/kaggle/input/datasets/asoktamang/saddie-sink/sadie_sink.jpg")

# %%
image_classifier = pipeline(
    task="image-classification", model="google/vit-base-patch16-224", use_fast = True
)
result = image_classifier(
    image
)
print(result)
# Out:
# config.json: 0.00B [00:00, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/200 [00:00<?, ?it/s]
# preprocessor_config.json:   0%|          | 0.00/160 [00:00<?, ?B/s]
# Fast image processor class <class 'transformers.models.vit.image_processing_vit_fast.ViTImageProcessorFast'> is available for this model. Using slow image processor class. To use the fast image processor class set `use_fast=True`.
# [{'label': 'gown', 'score': 0.32991695404052734}, {'label': 'brassiere, bra, bandeau', 'score': 0.057842422276735306}, {'label': 'overskirt', 'score': 0.045211490243673325}, {'label': 'maillot', 'score': 0.036676160991191864}, {'label': 'hair spray', 'score': 0.036006949841976166}]

# %% [markdown]
# Fine tuning a text generation model

# %%
from datasets import load_dataset

train_data = load_dataset("dany0407/eli5_category", split="train[:5000]")
# Out:
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001.parquet:   0%|          | 0.00/98.6M [00:00<?, ?B/s]
# data/validation1-00000-of-00001.parquet:   0%|          | 0.00/7.92M [00:00<?, ?B/s]
# data/validation2-00000-of-00001.parquet:   0%|          | 0.00/2.78M [00:00<?, ?B/s]
# data/test-00000-of-00001.parquet:   0%|          | 0.00/6.09M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/91772 [00:00<?, ? examples/s]
# Generating validation1 split:   0%|          | 0/5446 [00:00<?, ? examples/s]
# Generating validation2 split:   0%|          | 0/2375 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/5411 [00:00<?, ? examples/s]

# %%
train_data[0]['answers']['text']
# Out:
# ['the rotation of the earth is not a constant. in fact the rotation of the earth is slowing down, which means that a full day is getting slightly longer. without leap seconds our clocks would slowly drift ever so slightly out of sync with the actual day. we could deal with this by redefining how how long 1 second is, making it slightly longer so that one day is still exactly 24*60*60 seconds. but in practice that is really inconvenient for a lot of our technology which relies on very precise timing. its easier to just move us ahead one second every couple of years or so.',
#  "The Earth's rotation is not regular. It varies a bit, so sometimes we add a second. We do this to ensure that noon is always going to be sometime around mid-day. If we did not add leap seconds, over a very long period of time where the Earth's rotation slowly changed, noon could end up being at dusk. We want to keep 7am in the morning, noon at mid-day, 7pm around evening, etc. Though we have never had one, it's also possible to have a negative leap second. That is, taking away a second from the year. This has never happened, but if the Earth's rotation were to speed up, it could happen. The biggest thing to know about leap seconds is that they can cause computer problems. You might remember the Y2K bug. A leap second can cause similar problems, and they actually have caused problems in the past. The reason for this is that generally we expect a day to have 24 hours, and for time to always move forward. With a leap second this is not true. When writing software, programers try to think of all the possible exceptions that could happen withing their code. For example, the program might expect a word, but instead get a number. A good programmer will check for these exceptions and deal with them. However, a programer can easily forget about leap seconds and not have a fail-safe in their code for when a day have more than 24 hours. When such an exception happens, the program can produce errors or crash. It is an interesting topic, you can read more about it here: URL_0",
#  "Because the Earth's rotation is slowing. If you multiply 24 hours by 60 minutes by 60 seconds, you find that there are 86400 seconds per day. The problem is that our definition of the second is based on [an average that is a century old.]( URL_0 ) In modern times, the average day is about 2 thousandths of a second longer—again, because of Earth's slowing rotation. Those thousandths of a second add up, so every few years we have to slip in an extra second to account for them. Without leap seconds, we'd eventually end up with noon at 7 o'clock, though admittedly, this would take a very long time."]

# %%
train_data = train_data.flatten()

# %% [markdown]
# Loading the auto tokenizer

# %%
tokenizer = AutoTokenizer.from_pretrained("distilbert/distilgpt2")
# Out:
# config.json:   0%|          | 0.00/762 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]

# %%
def apply_tokenizer(data):
    return tokenizer([' '.join(x) for x in data['answers.text']])

# %% [markdown]
# applying the tokenizer function on all the examples of training data

# %%
tokenized_train_data = train_data.map(apply_tokenizer,
                                     batched = True,
                                     num_proc = 4,
                                     remove_columns = train_data.column_names)
# Out:
# Map (num_proc=4):   0%|          | 0/5000 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (1173 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1576 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (4271 > 1024). Running this sequence through the model will result in indexing errors
# Token indices sequence length is longer than the specified maximum sequence length for this model (1823 > 1024). Running this sequence through the model will result in indexing errors

# %% [markdown]
# Grouping the tokens into the limited chunks and this below approach does save the data, even though the number of tokens are shorter than the block-size.

# %%
block_size = 128
def group_into_chunks(x):
    concatated_data = {k: sum(x[k],[]) for k in x.keys()}  #making a dictionary based on the key and the tokens as the values
    total_length = len(concatated_data[list(x.keys())[0]])  #here we are only counting the length of the input_ids excluding that of the attention mask
    if total_length >= block_size:  #if the total length exceeds the block size then we must limit the total length within the block size chunks
        total_length = (total_length // block_size) * block_size
    result = {
        k:[t[i:i+block_size] for i in range(0,total_length,block_size)] for k,t in concatated_data.items() 
    }    #here we are storing the final range of tokens within the limit of block_size and storing the tokens based on the key
    result['labels'] = result['input_ids'].copy()  #then finalizing the result with the key labels only escaping the other key such as the paddings and so on
    return result

# %% [markdown]
# Grouping the training data into chunks

# %%
grouped_train_data = tokenized_train_data.map(group_into_chunks,batched = True , num_proc = 4)
# Out:
# Map (num_proc=4):   0%|          | 0/5000 [00:00<?, ? examples/s]

# %% [markdown]
# The below approach doesnot save the datas as the tokens which are shorter than the block-size are dropped.

# %%
def tokenize_element(data):
    outputs = tokenizer(
        [' '.join(x) for x in data['answers.text']],
        truncation = True,
        max_length = block_size,   #the length-limit of the token is the block_size 
        return_overflowing_tokens = True,
        return_length = True
        )
    input_batch = []
    for length, input_ids in zip(outputs['length'],outputs['input_ids']):
        #if the length of the tokens is within the context length then only we append this token in the input batch
        if length == block_size: 
          input_batch.append(input_ids)
    return {'input_ids':input_batch}
tokenized_datasets =   train_data.map(tokenize_element,batched= True, remove_columns = train_data.column_names)
# Out:
# Map:   0%|          | 0/5000 [00:00<?, ? examples/s]

# %% [markdown]
# Preparing data-collator for casual language modeling

# %%
from transformers import DataCollatorForLanguageModeling
tokenizer.pad_token = tokenizer.eos_token  #setting the pad token of tokenizer to end of sequence token
data_collator = DataCollatorForLanguageModeling(tokenizer = tokenizer, mlm = False)

# %%
from transformers import AutoModelForCausalLM, TrainingArguments, Trainer
